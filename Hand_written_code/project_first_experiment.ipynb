# %%
import math
import numpy as np
import pandas as pd
from read_data_file import *
from util import *
from train_model import *

file_name = "/Users/fahimtajwar/Academics/CS229A/Project_Data/data/fdadatafinal.xlsx"
dataset_reader = Dataset_Reader(file_name, "excel")
dataset_divider = Dataset_Divider(dataset_reader)

# %%
print(dataset_divider.total_dataset.get_number_of_datapoints())
print(dataset_divider.training_dataset.get_number_of_datapoints())

print(dataset_divider.get_total_dataset().class_distribution)
# Out:
# 8079
# 4847
# {0: 1393, 1: 5850, 2: 836}

# %%
training_dataset = dataset_divider.get_training_dataset()

X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
indices = [4]
X_train = X_train[:, indices]
print(X_train.shape)
print(y_train.shape)

training_dataset_1 = Dataset(X_train, y_train)
model = Linear_Model("svm", training_dataset_1)
# Out:
# (4847, 1)
# (4847,)

# %%
average_loss_history, train_accuracies, per_class  = model.train(learning_rate = 5e-2, reg = 0.2, num_epochs = 100, 
                                   batch_size = "all", num_average = 10, decay = 0.95)
show_plot(average_loss_history, x_title = "Iteration", y_title = "Training loss")
show_plot(train_accuracies, x_title = "Iteration", y_title = "Training Accuracies")
print(max(train_accuracies))
print(max(train_accuracies) - min(train_accuracies))
print(per_class)
plot_bar_graph_from_map(per_class)
# Out:
# 0.3645553950897462
# 0.10336290488962241
# {0: 1.0, 1: 0.26847360912981455, 2: 0.0}

# %%
print(train_accuracies)
# Out:
# [0.2611924902001238, 0.3645553950897462, 0.3645553950897462, 0.3645553950897462, 0.3645553950897462, 0.3645553950897462, 0.3645553950897462, 0.3645553950897462, 0.3645553950897462, 0.3645553950897462]

# %%
print(training_dataset.get_class_distribution())
# Out:
# {0: 826, 1: 3505, 2: 516}

# %%
even_dataset_split = Balanced_Class_Dataset_Divider(dataset_reader)
training_dataset = even_dataset_split.get_training_dataset()
validation_dataset = even_dataset_split.get_validation_dataset()
test_dataset = even_dataset_split.get_test_dataset()

print(training_dataset.get_class_distribution())
print(validation_dataset.get_class_distribution())
print(test_dataset.get_class_distribution())
# Out:
# {0: 480, 1: 508, 2: 516}
# {0: 179, 1: 148, 2: 174}
# {0: 175, 1: 180, 2: 146}

# %%
X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
X_train = X_train[:, indices]
print(X_train.shape)
print(y_train.shape)

training_dataset = Dataset(X_train, y_train)
model = Linear_Model("svm", training_dataset)
# Out:
# (1504, 1)
# (1504,)

# %%
average_loss_history, train_accuracies, per_class  = model.train(learning_rate = 1e-3, reg = 0.2, num_epochs = 100, 
                                   batch_size = "all", num_average = 1, decay = 0.95)
show_plot(average_loss_history, x_title = "Iteration", y_title = "Training loss")
show_plot(train_accuracies, x_title = "Iteration", y_title = "Training Accuracies")
print(max(train_accuracies))
print(max(train_accuracies) - min(train_accuracies))
print(per_class)
# Out:
# 0.6170212765957447
# 0.0
# {0: 1.0, 1: 0.0, 2: 0.8682170542635659}

# %%
print(train_accuracies[len(train_accuracies) - 1])
# Out:
# 0.6170212765957447

# %%
print(model.get_accuracy(training_dataset_1.get_X(), training_dataset_1.get_y()))
# Out:
# 0.2611924902001238

# %%
print(model.get_per_class_accuracy(training_dataset_1.get_X(), training_dataset_1.get_y()))
# Out:
# {0: 1.0, 1: 0.0, 2: 0.8527131782945736}

# %%
visualize_dataset(even_dataset_split.get_separated_dataset(), 100, 4, 3)

# %%
bn_reader = Binary_Dataset_Reader(file_name, "excel")
total_dt = bn_reader.get_total_dataset()
print(total_dt.get_class_distribution())
# Out:
# {0: 7243, 1: 836}
# {0: 836, 1: 836}

# %%
visualize_dataset(bn_reader.get_separated_dataset(), 10, 3, 1, "Device Type", "Quantity Produced", labels = ["Not Risky (Class I and II)", "Risky (Class III)"])

# %%
training_dataset = bn_reader.get_training_dataset()
X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
X_train = X_train[:, indices]
print(X_train.shape)
print(y_train.shape)
print(training_dataset.get_class_distribution())

training_dataset = Dataset(X_train, y_train)
model = Linear_Model("svm", training_dataset, binary_classification = True, weight_scale = 0.01)

average_loss_history, train_accuracies, per_class  = model.train(learning_rate = 1e-3, reg = 0.2, num_epochs = 100, 
                                   batch_size = "all", num_average = 1, decay = 0.95)
show_plot(average_loss_history, x_title = "Iteration", y_title = "Training loss")
show_plot(train_accuracies, x_title = "Iteration", y_title = "Training Accuracies")
print(max(train_accuracies))
print(max(train_accuracies) - min(train_accuracies))
print(per_class)
print(train_accuracies)
plot_bar_graph_from_map(per_class)
# Out:
# (1003, 1)
# (1003,)
# {0: 510, 1: 493}
# 0.8175473579262214
# 0.0
# {0: 0.788235294117647, 1: 0.847870182555781}
# [0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214, 0.8175473579262214]

# %%
model.print_vital_statistics_for_training_model()
print(model.confusion_matrix)
# Out:
# 0.847870182555781
# 0.788235294117647
# 0.21176470588235297
# 0.15212981744421905
# 0.7946768060836502
# 0.847870182555781
# 0.8204121687929342
# (418, 402, 108, 75)
