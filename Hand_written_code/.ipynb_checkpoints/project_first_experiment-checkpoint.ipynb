# %%
import math
import numpy as np
import pandas as pd
from read_data_file import *
from util import *
from train_model import *

file_name = "/Users/fahimtajwar/Academics/CS229A/Project_Data/data/fdadatafinal.xlsx"
dataset_reader = Dataset_Reader(file_name, "excel")
dataset_divider = Dataset_Divider(dataset_reader)

# %%
print(dataset_divider.total_dataset.get_number_of_datapoints())
print(dataset_divider.training_dataset.get_number_of_datapoints())

print(dataset_divider.get_total_dataset().class_distribution)
# Out:
# 8079
# 4847
# {0: 1393, 1: 5850, 2: 836}

# %%
training_dataset = dataset_divider.get_training_dataset()

X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
indices = [4]
X_train = X_train[:, indices]
print(X_train.shape)
print(y_train.shape)

training_dataset_1 = Dataset(X_train, y_train)
model = Linear_Model("svm", training_dataset_1)
# Out:
# (4847, 1)
# (4847,)

# %%
average_loss_history, train_accuracies, per_class  = model.train(learning_rate = 5e-2, reg = 0.2, num_epochs = 100, 
                                   batch_size = "all", num_average = 10, decay = 0.95)
show_plot(average_loss_history, x_title = "Iteration", y_title = "Training loss")
show_plot(train_accuracies, x_title = "Iteration", y_title = "Training Accuracies")
print(max(train_accuracies))
print(max(train_accuracies) - min(train_accuracies))
print(per_class)
# Out:
# 0.3647617082731587
# 0.0
# {0: 1.0, 1: 0.2602895259721828, 2: 0.0}

# %%
print(train_accuracies)
# Out:
# [0.3647617082731587, 0.3647617082731587, 0.3647617082731587, 0.3647617082731587, 0.3647617082731587, 0.3647617082731587, 0.3647617082731587, 0.3647617082731587, 0.3647617082731587, 0.3647617082731587]

# %%
print(training_dataset.get_class_distribution())
# Out:
# {0: 851, 1: 3523, 2: 473}

# %%
even_dataset_split = Balanced_Class_Dataset_Divider(dataset_reader)
training_dataset = even_dataset_split.get_training_dataset()
validation_dataset = even_dataset_split.get_validation_dataset()
test_dataset = even_dataset_split.get_test_dataset()

print(training_dataset.get_class_distribution())
print(validation_dataset.get_class_distribution())
print(test_dataset.get_class_distribution())
# Out:
# {0: 494, 1: 496, 2: 514}
# {0: 177, 1: 169, 2: 155}
# {0: 164, 1: 171, 2: 166}

# %%
X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
X_train = X_train[:, indices]
print(X_train.shape)
print(y_train.shape)

training_dataset = Dataset(X_train, y_train)
model = Linear_Model("svm", training_dataset)
# Out:
# (1504, 1)
# (1504,)

# %%
average_loss_history, train_accuracies, per_class  = model.train(learning_rate = 1e-3, reg = 0.2, num_epochs = 100, 
                                   batch_size = "all", num_average = 1, decay = 0.95)
show_plot(average_loss_history, x_title = "Iteration", y_title = "Training loss")
show_plot(train_accuracies, x_title = "Iteration", y_title = "Training Accuracies")
print(max(train_accuracies))
print(max(train_accuracies) - min(train_accuracies))
print(per_class)
# Out:
# 0.6190159574468085
# 0.20678191489361697
# {0: 1.0, 1: 0.0, 2: 0.8501945525291829}

# %%
print(train_accuracies[len(train_accuracies) - 1])
# Out:
# 0.6190159574468085

# %%
print(model.get_accuracy(training_dataset_1.get_X(), training_dataset_1.get_y()))
# Out:
# 0.2605735506498865

# %%
print(model.get_per_class_accuracy(training_dataset_1.get_X(), training_dataset_1.get_y()))
# Out:
# {0: 1.0, 1: 0.0, 2: 0.8710359408033826}

# %%
visualize_dataset(even_dataset_split.get_separated_dataset(), 100, 4, 3)

# %%
bn_reader = Binary_Dataset_Reader(file_name, "excel")
total_dt = bn_reader.get_total_dataset()
print(total_dt.get_class_distribution())
# Out:
# {0: 7243, 1: 836}
# {0: 836, 1: 836}

# %%
visualize_dataset(bn_reader.get_separated_dataset(), 10, 3, 1, "Device Type", "Quantity Produced", labels = ["Not Risky (Class I and II)", "Risky (Class III)"])

# %%
training_dataset = bn_reader.get_training_dataset()
X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
X_train = X_train[:, indices]
print(X_train.shape)
print(y_train.shape)
print(training_dataset.get_class_distribution())

training_dataset = Dataset(X_train, y_train)
model = Linear_Model("logistic", training_dataset, binary_classification = True, weight_scale = 0.01)

average_loss_history, train_accuracies, per_class  = model.train(learning_rate = 1e-3, reg = 0.2, num_epochs = 100, 
                                   batch_size = "all", num_average = 1, decay = 0.95)
show_plot(average_loss_history, x_title = "Iteration", y_title = "Training loss")
show_plot(train_accuracies, x_title = "Iteration", y_title = "Training Accuracies")
print(max(train_accuracies))
print(max(train_accuracies) - min(train_accuracies))
print(per_class)
print(train_accuracies)
# Out:
# (1003, 1)
# (1003,)
# 0.8354935194416749
# 0.0
# {0: 0.7988165680473372, 1: 0.8729838709677419}
# [0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749, 0.8354935194416749]

# %%
model.print_vital_statistics_for_training_model()
print(model.confusion_matrix)
# Out:
# 0.8729838709677419
# 0.7988165680473372
# 0.20118343195266275
# 0.12701612903225812
# 0.8093457943925234
# 0.8729838709677419
# (433, 405, 102, 63)
