# %%
# author: Fahim Tajwar
from read_data_file import *
from util import *
from svm import *
from logistic_regression_scikit import *

# %%
file_name = "/Users/fahimtajwar/Academics/CS229A/Project_Data/data/fdadatafinalscalewithdescription.csv"
dataset_divider = NLPDatasetReader(file_name, "csv", intended_class = 2)

# %%
print(dataset_divider.total_dataset.get_number_of_datapoints())
print(dataset_divider.training_dataset.get_number_of_datapoints())
class_distribution = dataset_divider.get_total_dataset().get_class_distribution()
print(class_distribution)
print(dataset_divider.training_dataset.get_number_of_features())
# Out:
# 8079
# 4847
# {0: 7243, 1: 836}
# 32

# %%
training_dataset = dataset_divider.get_training_dataset()

X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
print(X_train.shape)
print(y_train.shape)

val_dataset = dataset_divider.get_validation_dataset()

X_val = val_dataset.get_X()
y_val = val_dataset.get_y()
print(X_val.shape)
print(y_val.shape)

test_dataset = dataset_divider.get_test_dataset()

X_test = test_dataset.get_X()
y_test = test_dataset.get_y()
print(X_test.shape)
print(y_test.shape)
# Out:
# (4847, 32)
# (4847,)
# (1615, 32)
# (1615,)
# (1615, 32)
# (1615,)

# %%
model = LinearSVMModel()
model.train(X_train, y_train)
# Out:
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
model.get_accuracy(X_train, y_train)
# Out:
# 0.7984320198060656

# %%
model.show_confusion_matrix(X_val, y_val)
model.get_model_statistics(X_val, y_val)
# Out:
# True Positive Rate:  0.8333333333333334
# True Negative Rate:  0.7818815331010452
# False Positive Rate:  0.21811846689895475
# False Negative Rate:  0.16666666666666663
# Precision :  0.32397408207343414
# Recall :  0.8333333333333334
# F1 Score :  0.46656298600311047
# Accuracy :  0.7876160990712074

# %%
model.show_roc_curve(X_val, y_val)

# %%
model = SVMGaussian()
model.train(X_train, y_train)
# Out:
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
model.get_accuracy(X_train, y_train)
# Out:
# 0.8275221786672169

# %%
model.show_confusion_matrix(X_val, y_val)
model.get_model_statistics(X_val, y_val)
# Out:
# True Positive Rate:  0.7777777777777778
# True Negative Rate:  0.8013937282229965
# False Positive Rate:  0.19860627177700352
# False Negative Rate:  0.2222222222222222
# Precision :  0.32941176470588235
# Recall :  0.7777777777777778
# F1 Score :  0.4628099173553719
# Accuracy :  0.7987616099071208

# %%
model.show_roc_curve(X_val, y_val)

# %%
model = LogRegModel()
model.train(X_train, y_train)

# %%
model.show_confusion_matrix(X_val, y_val)
model.get_model_statistics(X_val, y_val)
# Out:
# True Positive Rate:  0.8166666666666667
# True Negative Rate:  0.7853658536585366
# False Positive Rate:  0.21463414634146338
# False Negative Rate:  0.18333333333333335
# Precision :  0.3230769230769231
# Recall :  0.8166666666666667
# F1 Score :  0.46299212598425193
# Accuracy :  0.7888544891640867

# %%
model.show_roc_curve(X_val, y_val)

# %%
dataset_divider = NLPDatasetReader(file_name, "csv", intended_class = None)

print(dataset_divider.total_dataset.get_number_of_datapoints())
print(dataset_divider.training_dataset.get_number_of_datapoints())
class_distribution = dataset_divider.get_total_dataset().get_class_distribution()
print(class_distribution)
print(dataset_divider.training_dataset.get_number_of_features())

training_dataset = dataset_divider.get_training_dataset()

X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
print(X_train.shape)
print(y_train.shape)

val_dataset = dataset_divider.get_validation_dataset()

X_val = val_dataset.get_X()
y_val = val_dataset.get_y()
print(X_val.shape)
print(y_val.shape)

test_dataset = dataset_divider.get_test_dataset()

X_test = test_dataset.get_X()
y_test = test_dataset.get_y()
print(X_test.shape)
print(y_test.shape)
# Out:
# 8079
# 4847
# {0: 1393, 1: 5850, 2: 836}
# 32
# (4847, 32)
# (4847,)
# (1615, 32)
# (1615,)
# (1615, 32)
# (1615,)

# %%
model = SVMGaussian()
model.train(X_train, y_train)
# Out:
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
model.show_confusion_matrix(X_val, y_val)

# %%
model = LinearSVMModel()
model.train(X_train, y_train)
model.show_confusion_matrix(X_val, y_val)
# Out:
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
model = LogRegModel()
model.train(X_train, y_train)
model.show_confusion_matrix(X_val, y_val)
