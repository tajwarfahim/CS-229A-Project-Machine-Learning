# %%
# author: Fahim Tajwar
from read_data_file import *
from util import *
from svm import *

# %%
file_name = "/Users/fahimtajwar/Academics/CS229A/Project_Data/data/fdadatafinal.xlsx"
dataset_reader = Dataset_Reader(file_name, "excel")
dataset_divider = Dataset_Divider(dataset_reader)

# %%
print(dataset_divider.total_dataset.get_number_of_datapoints())
print(dataset_divider.training_dataset.get_number_of_datapoints())
class_distribution = dataset_divider.get_total_dataset().get_class_distribution()
print(class_distribution)
print(dataset_divider.training_dataset.get_number_of_features())
# Out:
# 8079
# 4847
# {0: 1393, 1: 5850, 2: 836}
# 5

# %%
training_dataset = dataset_divider.get_training_dataset()

X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
indices = [3, 4]
X_train = X_train[:, indices]
print(X_train.shape)
print(y_train.shape)

val_dataset = dataset_divider.get_validation_dataset()

X_val = val_dataset.get_X()
y_val = val_dataset.get_y()
X_val = X_val[:, indices]
print(X_val.shape)
print(y_val.shape)

test_dataset = dataset_divider.get_test_dataset()

X_test = test_dataset.get_X()
y_test = test_dataset.get_y()
X_test = X_test[:, indices]
print(X_test.shape)
print(y_test.shape)
# Out:
# (4847, 2)
# (4847,)
# (1615, 2)
# (1615,)
# (1615, 2)
# (1615,)

# %%
model = LinearSVMModel()

# %%
model.train(X_train, y_train)
# Out:
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
model.get_accuracy(X_train, y_train)
# Out:
# 0.6304930885083557

# %%
model.get_accuracy(X_val, y_val)
# Out:
# 0.6167182662538699

# %%
model.get_accuracy(X_test, y_test)
# Out:
# 0.6037151702786377

# %%
model.show_confusion_matrix(X_test, y_test)

# %%
per_class_accuracy = model.get_accuracy_map_per_class(X_test, y_test)

label_for_each_class = ["Risk Class I", "Risk Class II", "Risk Class III"]
x_label = "FDA Risk Classes of Medical Devices"
y_label = "Accuracy per class"
print(per_class_accuracy)
plot_bar_graph_from_map(per_class_accuracy, x_label, y_label, label_for_each_class)
# Out:
# {1: 0.7277441659464131, 0: 0.0, 2: 0.8417721518987342}

# %%
dataset_divider = Binary_Even_Dataset_Reader(file_name, "excel")
training_dataset = dataset_divider.get_training_dataset()

X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
X_train = X_train[:, indices]
print(X_train.shape)
print(y_train.shape)

val_dataset = dataset_divider.get_validation_dataset()

X_val = val_dataset.get_X()
y_val = val_dataset.get_y()
X_val = X_val[:, indices]
print(X_val.shape)
print(y_val.shape)

test_dataset = dataset_divider.get_test_dataset()

X_test = test_dataset.get_X()
y_test = test_dataset.get_y()
X_test = X_test[:, indices]
print(X_test.shape)
print(y_test.shape)
# Out:
# {0: 7243, 1: 836}
# (1003, 2)
# (1003,)
# (334, 2)
# (334,)
# (334, 2)
# (334,)

# %%
model = LinearSVMModel()
model.train(X_train, y_train)

# %%
print(model.get_accuracy(X_train, y_train))
# Out:
# 0.8205383848454636

# %%
C_values = [30, 0.3, 0.1, 1, 3, 10]
validation_linear_SVM(C_values, X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 30
# 0.8579234972677596
# 0.8413173652694611
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# True Positive Rate:  0.8888888888888888
# True Negative Rate:  0.7914110429447853
# False Positive Rate:  0.20858895705521474
# False Negative Rate:  0.11111111111111116
# Precision :  0.8172043010752689
# Recall :  0.8888888888888888
# F1 Score :  0.8515406162464986
# Accuracy :  0.8413173652694611

# %%
model = SVMGaussian()
model.train(X_train, y_train)
model.get_accuracy(X_train, y_train)
# Out:
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.8205383848454636

# %%
validation_Gaussian_SVM(C_values, X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# 0.3
# 0.8579234972677596
# 0.8413173652694611
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# True Positive Rate:  0.8888888888888888
# True Negative Rate:  0.7914110429447853
# False Positive Rate:  0.20858895705521474
# False Negative Rate:  0.11111111111111116
# Precision :  0.8172043010752689
# Recall :  0.8888888888888888
# F1 Score :  0.8515406162464986
# Accuracy :  0.8413173652694611

# %%
dataset_reader = Dataset_Reader(file_name, "excel")
dataset_divider = Dataset_Divider(dataset_reader)

training_dataset = dataset_divider.get_training_dataset()

X_train = training_dataset.get_X()
y_train = training_dataset.get_y()
indices = [3, 4]
X_train = X_train[:, indices]
print(X_train.shape)
print(y_train.shape)

val_dataset = dataset_divider.get_validation_dataset()

X_val = val_dataset.get_X()
y_val = val_dataset.get_y()
X_val = X_val[:, indices]
print(X_val.shape)
print(y_val.shape)

test_dataset = dataset_divider.get_test_dataset()

X_test = test_dataset.get_X()
y_test = test_dataset.get_y()
X_test = X_test[:, indices]
print(X_test.shape)
print(y_test.shape)
# Out:
# (4847, 2)
# (4847,)
# (1615, 2)
# (1615,)
# (1615, 2)
# (1615,)

# %%
validation_Gaussian_SVM(C_values, X_train, y_train, X_val, y_val, X_test, y_test, multi_class = True)
# Out:
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.1
# 0.6589147286821706
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.6526315789473685

# %%
model = SVMGaussian()
model.train(X_train, y_train)
print(model.get_accuracy(X_test, y_test))

per_class_accuracy = model.get_accuracy_map_per_class(X_test, y_test)
print(per_class_accuracy)

model.show_confusion_matrix(X_test, y_test)
label_for_each_class = ["Risk Class I", "Risk Class II", "Risk Class III"]
x_label = "FDA Risk Classes of Medical Devices"
y_label = "Accuracy per class"
plot_bar_graph_from_map(per_class_accuracy, x_label, y_label, label_for_each_class)
# Out:
# /Users/fahimtajwar/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.6445820433436532
# {1: 0.5545927209705372, 0: 0.8741496598639455, 2: 0.8622754491017964}
